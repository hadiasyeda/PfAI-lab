# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('C:\\Users\\Administrator\\Downloads\\download (11).jfif') 


img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)


plt.imshow(img_rgb)
plt.axis('off')
plt.show()

# %%
resized_img = cv2.resize(img, (300, 300)) 

cropped_img = img[50:250, 50:250]


plt.imshow(cv2.cvtColor(cropped_img, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

plt.imshow(gray, cmap='gray')
plt.axis('off')
plt.show()

# %%
img_copy = img.copy()
cv2.rectangle(img_copy, (50,50), (200,200), (255,0,0), 3)  # blue rectangle


cv2.circle(img_copy, (150,150), 50, (0,255,0), -1)  # green filled circle

plt.imshow(cv2.cvtColor(img_copy, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

# %%
_, thresh = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)

plt.imshow(thresh, cmap='gray')
plt.axis('off')
plt.show()

# %%
edges = cv2.Canny(gray, 100, 200)

plt.imshow(edges, cmap='gray')
plt.axis('off')
plt.show()

# %%
contours, _ = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

img_contour = img.copy()
cv2.drawContours(img_contour, contours, -1, (0,255,0), 2)

plt.imshow(cv2.cvtColor(img_contour, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

# %%
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5)

img_faces = img.copy()
for (x,y,w,h) in faces:
    cv2.rectangle(img_faces, (x,y), (x+w, y+h), (255,0,0), 2)

plt.imshow(cv2.cvtColor(img_faces, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()
